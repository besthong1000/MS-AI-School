# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# ...
#      ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#      ---------------------------------------- 0.1/7.5 MB 655.4 kB/s eta 0:00:12
#       --------------------------------------- 0.2/7.5 MB 833.5 kB/s eta 0:00:09
#      - -------------------------------------- 0.3/7.5 MB 1.2 MB/s eta 0:00:06
#      - -------------------------------------- 0.4/7.5 MB 1.3 MB/s eta 0:00:06
#      -- ------------------------------------- 0.4/7.5 MB 1.3 MB/s eta 0:00:06
#      -- ------------------------------------- 0.5/7.5 MB 1.3 MB/s eta 0:00:06
#      -- ------------------------------------- 0.5/7.5 MB 1.3 MB/s eta 0:00:06
#      --- ------------------------------------ 0.6/7.5 MB 1.4 MB/s eta 0:00:05
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import wilcoxon
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
#       4 from scipy.stats import wilcoxon
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
#데이터불러오기
data = pd.read_csv('./data/treatement_data.csv')

# 두변수간의 차이검정
stat, p = wilcoxon(data['pre_treatment'], data['post_treatment'])

# %% [markdown]
# ### 검정결과 시각화

# %%
sns.boxplot(data=data[['pre_treatment','post_trearment']], palette="set3")
sns.stripplot(data=data[['pre_treatment','post_treatment']], color='.3', size=4)
sns.despine(trim=True)
if p > 0.05 :
    plt.title('Wilcoxon signed-rank test\nSame distribution\n p-value=%.3f'% (p))
else :
    plt.title('Wilcoxon signed-rank test\n Different distribution\np-value=%.3f'%(p))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.boxplot(data=data[['pre_treatment','post_trearment']], palette="set3")
#       2 sns.stripplot(data=data[['pre_treatment','post_treatment']], color='.3', size=4)
#       3 sns.despine(trim=True)
#
# NameError: name 'sns' is not defined
