# %% [markdown]
# <a href="https://colab.research.google.com/github/unihong/MS-AI-School/blob/main/20230720_01_SIFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# IMAGE LOADER
image = cv2.imread("./icecream.jpg")
image = cv2.resize(image, (400, 400))

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# SIFT 객체 생성
sift = cv2.SIFT_create()

# Keypoint 검출 및 특징 드스크립터 계산
keypoints, descriptors = sift.detectAndCompute(gray, None)

# 키포인트 그리기
image_with_keypoints = cv2.drawKeypoints(image, keypoints, None)

# 결과 이미지 출력
cv2_imshow(image_with_keypoints)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7B9ACC57E680>
